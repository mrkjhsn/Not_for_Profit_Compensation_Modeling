# %% [markdown]
# #### Final Capstone Proposal
#
# 1. What is the problem you are attempting to solve?
# How much such a not-for-profit organization pay it's top management?  Not-for-profit organizations devoted to specific causes have a huge amount of variablity (revenue, number of volunteers, ect.).  How much should not-for-profits award their top managment?
#
# 1. How is your solution valuable?
# The not-for-profit world doesn't operate by the same rules as the for-profit world.  For instance, some not-for-profit managers might be willing to volunteer their time, or take a pay cut to be involved with an organization they believe in.
#
# 1. What is your data source and how will you access it?
# I will use two data sources made available by Open990(https://www.open990.org/catalog/), an organization dedicated to promoting not-for-profit transparency.  One dataset includes governance information, while the other includes compensation amounts paid to top employees.  Both of these datasets will be downloaded from the above website link in csv format.  Each of them are several million rows in length.
#
# 1. What techniques from the course do you anticipate using?
# I anticipate using unsupervised learning on the Governance dataset to be able to find organizations that are similar to each other based on information such as number of volunteers or number of independent voting members.  Based on the categories obtained from this step I will use supervised learning on the Compensation datset which includes financial information such as the net assests of the organization to predict the salaries of the not-for-profits top management.
#
# 1. What do you anticipate to be the biggest challenge you’ll face?
#
# Based on my initial review of the dataset, I believe my biggest challenge will be to effectively cluster using unsupervised learning on the Governance dataset.  Since not-for-profit organizations have such huge size differences from hospitals(lots of fixed assets) to reproductive rights advocacy(lots of volunteers) I think it will be tricky to effectively group them in a way that can be beneficial for the second phase using supervised learning.

# %% [markdown]
# ### Research questions to consider:
# How does the formation year affect compensation?
#
# How does the NTEE description affect compensation?
#
# Organizations with segregation of duties concerns "Clerk, Treas., Dir."
#
# Organizations who are likely paying their management more than they should.  Come up with a dollar per/hour ratio.
#
# For organizations who have xxx people working for them, this is the averge dollar value income.  What about organizations that fall outside those parameters?  Organizations with lots of money and only one person?
#
# _______________
# NTEE Descriptions have a huge amount of specificity https://learn.guidestar.org/help/ntee-codes
# Based on NTEE categories, what salary should be paid for top positions?
#
# Can I identify organizations who are paying significantly more?

# %% [markdown]
# ### From Governance Snack Dataset, add in:
#
#
# 1. ein Header/ Block D Employer Identification Number text
# 1. tax_yr N/A Year associated with tax_date_end text
# 1. voting_memb_ct Part I/ Line 3 Number of voting members of the governing body at the end of the year integer
# 1. voting_indepmemb_ct Part I/ Line 4 Number of independent voting members of the governing body at the end of the year integer employee_tot_ct 1. Part I/ Line 5 Number of employees integer volunteer_tot_ct
# 1. Part I/ Line 6 Number of volunteers integer
#
# 1. ceo_comp_review Part VI/Section B/Line 15a Have independent review of compensation for CEO, Executive Director, or top management official
# 1. binary officer_comp_review Part VI/Section B/Line 15b Have independent review of compensation for other officers or key employees of the organization binary

# %% [markdown]
# ### Process:
# 1. Use governance characteristics to cluster orgs.
# 1. Use cluster information from above to then predict Trustee or director salary

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Compensation_charities_Open990.csv', header=1)
# df = pd.read_csv('Compensation_charities_Open990.csv', nrows=30000, header=1)
# Out:
# C:\Users\mrkjh\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (38) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
# Out:
# (3990749, 48)

# %%
df.head()
# Out:
#         EIN  Period               Person ID         Title  Hours  \
# 0  10877614  201712  y7drw7umAm8SK9fWY7aFCA  BOARD MEMBER    1.0
# 1  10877614  201712  NPcAAprw13Optnp4Bio5og  BOARD MEMBER    1.0
# 2  10877614  201712  AcFe9lOktfzX4yAlRDDHsA  BOARD MEMBER    1.0
# 3  10877614  201712  MzSmGy0aHY9k7hkE_Y3EBQ  BOARD MEMBER    1.0
# 4  10877614  201712  hhCYV22sDcQfPzrFejcf-g  BOARD MEMBER    1.0
#
#    Hours related org Trustee or director Institutional trustee Officer  \
# 0                NaN                True                   NaN     NaN
# 1                NaN                True                   NaN     NaN
# 2                NaN                True                   NaN     NaN
# 3                NaN                True                   NaN     NaN
# 4                NaN                True                   NaN     NaN
#
#   Key employee Highest compensated Former  Reportable comp  \
# 0          NaN                 NaN    NaN              0.0
# ...

# %%
# because of the high variance to each of these categories
# cluster and label based on characteristics
# to create a more effective organization than 
# just the NTEE code
df.groupby('NTEE code')['Revenue'].agg(['min', 'max', 'var'])
# Out:
#                   min           max           var
# NTEE code
# A01               0.0  7.365021e+07  1.469259e+14
# A02               0.0  1.400675e+07  4.696663e+12
# A03        -1378019.0  1.427941e+08  2.838741e+14
# A05               0.0  1.420806e+07  1.005822e+13
# A11        -1463762.0  7.252340e+07  6.811448e+13
# ...               ...           ...           ...
# Y43       -10935589.0  4.359651e+09  6.068262e+16
# Y44              10.0  3.904413e+09  3.294273e+17
# Y50         -100219.0  1.543805e+08  5.602415e+13
# Y99           -6819.0  1.318940e+08  6.007856e+13
# Z99       -11917351.0  1.149624e+09  7.926117e+15
#
# [633 rows x 3 columns]

# %%
df['Period'].value_counts().sort_index()
# Out:
# 201701        643
# 201702        862
# 201703       3614
# 201704       1979
# 201705       4760
# 201706      81602
# 201707       4402
# 201708       8792
# 201709      16800
# 201710       2684
# 201711       3320
# 201712     983987
# 201801       5711
# 201802       6952
# 201803      45931
# 201804      25185
# 201805      64261
# 201806    1018386
# 201807      52774
# 201808     111790
# 201809     239001
# 201810      32875
# 201811      11487
# 201812    1077078
# 201901       6357
# 201902       7038
# 201903      37386
# 201904      16561
# 201905      22745
# 201906      90419
# 201907       2908
# 201908       1919
# 201909        515
# 210805         25
# Name: Period, dtype: int64

# %%
df['NTEE code'].value_counts()
# Out:
# S41    132385
# B11    114217
# J40     78004
# S80     69231
# S20     62799
#         ...
# L33        10
# P23         9
# V31         8
# B3O         3
# V34         3
# Name: NTEE code, Length: 633, dtype: int64

# %%
df['NTEE code'].nunique()
# Out:
# 633

# %%
df['Subsection'].value_counts()
# Out:
# 501(c)(3)     3040790
# 501(c)(6)      396563
# 501(c)(4)      144899
# 501(c)(5)      127732
# 501(c)(7)      101586
# 501(c)(8)       40372
# 501(c)(19)      31390
# 501(c)(9)       26111
# 501(c)(12)      24519
# 501(c)(14)      17317
# 501(c)(2)       14124
# 501(c)(13)      13432
# 501(c)(10)       8855
# 501(c)(25)       1317
# 501(c)(15)        673
# 4947(a)(1)        229
# 501(c)(17)        214
# 501(c)(29)        144
# 501(c)(1)          88
# 501(c)(27)         87
# 501(c)(16)         85
# 501(c)(23)         63
# 501(c)(26)         61
# 501(c)(11)         39
# 501(c)(50)         34
# 501(c)(71)         11
# 501(c)(18)          8
# 501(c)(20)          6
# Name: Subsection, dtype: int64

# %%
df[df['Trustee or director'] == True].shape
# Out:
# (2501613, 48)

# %%
df[df['Trustee or director'] == True].head()
# Out:
#         EIN  Period               Person ID         Title  Hours  \
# 0  10877614  201712  y7drw7umAm8SK9fWY7aFCA  BOARD MEMBER    1.0
# 1  10877614  201712  NPcAAprw13Optnp4Bio5og  BOARD MEMBER    1.0
# 2  10877614  201712  AcFe9lOktfzX4yAlRDDHsA  BOARD MEMBER    1.0
# 3  10877614  201712  MzSmGy0aHY9k7hkE_Y3EBQ  BOARD MEMBER    1.0
# 4  10877614  201712  hhCYV22sDcQfPzrFejcf-g  BOARD MEMBER    1.0
#
#    Hours related org Trustee or director Institutional trustee Officer  \
# 0                NaN                True                   NaN     NaN
# 1                NaN                True                   NaN     NaN
# 2                NaN                True                   NaN     NaN
# 3                NaN                True                   NaN     NaN
# 4                NaN                True                   NaN     NaN
#
#   Key employee Highest compensated Former  Reportable comp  \
# 0          NaN                 NaN    NaN              0.0
# ...

# %%
df[df['Highest compensated'] == True].shape
# Out:
# (97095, 48)

# %%
df[df['Key employee'] == True].shape
# Out:
# (46709, 48)

# %% [markdown]
# To handle multiple years, and multiple employees receiving different amounts
#     groupby each org, find the mean hours, mean reportable compensation, mean trustee or director salary, institutional trustee, ect.

# %%
df[df['Reportable comp'] == 0].shape
# Out:
# (3542467, 48)

# %%
df[df['Reportable comp'] != 0].shape
# Out:
# (448282, 48)

# %%
df.groupby('Org name')['Org name'].count().sort_values(ascending=False)
# Out:
# Org name
# HACKENSACK MERIDIAN HEALTH INC-SUBORDINATES    265
# EASTERN MAINE HEALTHCARE SYSTEMS                82
# Nationwide Children's Hospital Group Return     76
# COUNCIL OF INDEPENDENT COLLEGES                 53
# ALLIANCE                                        53
#                                               ...
# VIRGINIA GREYHOUND ADOPTION                      1
# SOUTH CAROLINA SEAFOOD ALLIANCE                  1
# CULTURALLY YOURS INTL                            1
# SOUTH FLORIDA DAY OF CARING INC                  1
# TRAN QUOC BUDDHIST TEMPLE                        1
# Name: Org name, Length: 3178, dtype: int64

# %%
HACKENSACK MERIDIAN HEALTH INC-SUBORDINATES

# %%
df[(df['Org name'] == 'HACKENSACK MERIDIAN HEALTH INC-SUBORDINATES')].shape
# Out:
# (265, 48)

# %%
df[(df['Org name'] == 'HACKENSACK MERIDIAN HEALTH INC-SUBORDINATES') &
  (df['Trustee or director'] == True)].head()
# Out:
#            EIN  Period               Person ID                     Title  \
# 8199  10649794  201712  nN1M-BylrPv-8qANemZrgg                   Trustee
# 8200  10649794  201712  SBs4U5i59CJj7Gc3DseqzA  Trustee - PRESIDENT SOMC
# 8202  10649794  201712  F2GreyncEcu_5-5fK-wFIA                   Trustee
# 8203  10649794  201712  dsRn45tk2qCtM037Lg2GiA                   Trustee
# 8204  10649794  201712  SSl5mcL5vOXDei5es5R5TQ                   Trustee
#
#       Hours  Hours related org Trustee or director Institutional trustee  \
# 8199    3.0                0.0                True                   NaN
# 8200   55.0                0.0                True                   NaN
# 8202    3.0                0.0                True                   NaN
# 8203    3.0                0.0                True                   NaN
# 8204    3.0                0.0                True                   NaN
#
#      Officer Key employee Highest compensated Former  Reportable comp  \
# ...

# %%
df_foundations = pd.read_csv('Compensation_foundations_Open990.csv', nrows=10000, header=1)

# %%
df_foundations.head()
# Out:
#         EIN  Period               Person ID           Title  Hours  \
# 0  10936787  201812  OjrhLMXsWwJQ7DJjFnmedw       TREASURER    3.0
# 1  10936787  201812  PfxAhwGU2Nafixszy1QA4Q        DIRECTOR    3.0
# 2  10936787  201812  OhLS2aOqUl2w5PnTvmPI_Q        PRES/SEC   10.0
# 3  10939828  201812  RJwFEd8bXfon5Zui7xRlmg  VICE PRESIDENT    1.0
# 4  10939828  201812  2ZHL1IgQT-mWPhBIWnKSlw       PRESIDENT    1.0
#
#    Compensation  Benefits  Allowances                Org name Subsection  \
# 0             0       NaN         NaN  NARROW GATE FOUNDATION  501(c)(3)
# 1             0       NaN         NaN  NARROW GATE FOUNDATION  501(c)(3)
# 2             0       NaN         NaN  NARROW GATE FOUNDATION  501(c)(3)
# 3             0       0.0         0.0  Agee Family Foundation  501(c)(3)
# 4             0       0.0         0.0  Agee Family Foundation  501(c)(3)
#
#   NTEE code                 NTEE description                        Street  \
# ...

# %%
df_foundations[df_foundations['Org name'] == 'NARROW GATE FOUNDATION']
# Out:
#         EIN  Period               Person ID      Title  Hours  Compensation  \
# 0  10936787  201812  OjrhLMXsWwJQ7DJjFnmedw  TREASURER    3.0             0
# 1  10936787  201812  PfxAhwGU2Nafixszy1QA4Q   DIRECTOR    3.0             0
# 2  10936787  201812  OhLS2aOqUl2w5PnTvmPI_Q   PRES/SEC   10.0             0
#
#    Benefits  Allowances                Org name Subsection NTEE code  \
# 0       NaN         NaN  NARROW GATE FOUNDATION  501(c)(3)       T22
# 1       NaN         NaN  NARROW GATE FOUNDATION  501(c)(3)       T22
# 2       NaN         NaN  NARROW GATE FOUNDATION  501(c)(3)       T22
#
#                   NTEE description           Street       City State    ZIP  \
# 0  Private Independent Foundations  98 NUTTALL ROAD  RIVERSIDE    IL  60546
# 1  Private Independent Foundations  98 NUTTALL ROAD  RIVERSIDE    IL  60546
# 2  Private Independent Foundations  98 NUTTALL ROAD  RIVERSIDE    IL  60546
#
#           Phone Website inspect  Assets  Liabilities  \
# ...

# %%
df_foundations['NTEE code'].nunique()
# Out:
# 244

# %%
df_foundations['NTEE code'].value_counts().head(30)
# Out:
# T20    2574
# T22    1834
# T90     542
# B82     406
# L99     228
# B11     185
# A82     168
# P75     159
# T21     130
# A50     127
# E11     113
# L22     111
# A80     104
# S20      83
# X20      82
# T03      79
# T23      75
# T99      71
# L80      63
# P99      61
# B20      57
# S41      50
# S80      50
# A99      49
# D20      47
# E99      47
# B70      45
# N12      44
# S21      43
# R24      42
# Name: NTEE code, dtype: int64

# %%
df_foundations['NTEE description'].value_counts()
# Out:
# Private Grantmaking Foundations                         2574
# Private Independent Foundations                         1834
# Named Trusts/Foundations N.E.C.                          542
# Scholarships, Student Financial Aid Services, Awards     406
# Housing, Shelter N.E.C.                                  228
#                                                         ...
# Rehabilitative Medical Services                            1
# Alliance/advocacy organization - Housing                   1
# Food Banks, Food Pantries                                  1
# Employment Procurement Assistance, Job Training            1
# Developmentally Disabled Centers, Services                 1
# Name: NTEE description, Length: 229, dtype: int64

# %%
df_foundations['Title'].value_counts()
# Out:
# TRUSTEE                2762
# DIRECTOR               1677
# Trustee                 576
# Director                545
# PRESIDENT               515
#                        ...
# Clerk, Treas., Dir.       1
# Scholarship Officer       1
# SUCCESSOR TRT             1
# MEMBERSHIP CHAIR          1
# Pres./Vice-Chair          1
# Name: Title, Length: 1052, dtype: int64

# %%
df.head()
# Out:
#         EIN  Period               Person ID         Title  Hours  \
# 0  10877614  201712  y7drw7umAm8SK9fWY7aFCA  BOARD MEMBER    1.0
# 1  10877614  201712  NPcAAprw13Optnp4Bio5og  BOARD MEMBER    1.0
# 2  10877614  201712  AcFe9lOktfzX4yAlRDDHsA  BOARD MEMBER    1.0
# 3  10877614  201712  MzSmGy0aHY9k7hkE_Y3EBQ  BOARD MEMBER    1.0
# 4  10877614  201712  hhCYV22sDcQfPzrFejcf-g  BOARD MEMBER    1.0
#
#    Hours related org Trustee or director Institutional trustee Officer  \
# 0                NaN                True                   NaN     NaN
# 1                NaN                True                   NaN     NaN
# 2                NaN                True                   NaN     NaN
# 3                NaN                True                   NaN     NaN
# 4                NaN                True                   NaN     NaN
#
#   Key employee Highest compensated Former  Reportable comp  \
# 0          NaN                 NaN    NaN                0
# ...

# %%
df[df['Reportable comp'] > 0].head()
# Out:
#          EIN  Period               Person ID                    Title  Hours  \
# 6   10877614  201712  7I-r1Fu7Vw0W_sYXaIWNNQ  BOARD MEMBER/MANAGING D   65.0
# 7   10877614  201712  FsnoEHXJ9ieEdcBs-ew29w             BOARD MEMBER   40.0
# 17  10878480  201806  UqU4ztC2HSE7wVYBZTGs5g          Executive Direc   60.0
# 22  10878619  201812  B1v49l2CYHxfzYv1hEotgw                President   40.0
# 24  10878619  201812  rIIk_772wAGfDvbFLpwNFw                Treasurer   40.0
#
#     Hours related org Trustee or director Institutional trustee Officer  \
# 6                 NaN                True                   NaN     NaN
# 7                 NaN                True                   NaN     NaN
# 17                NaN                 NaN                   NaN     NaN
# 22                NaN                 NaN                   NaN     NaN
# 24                NaN                 NaN                   NaN     NaN
#
#    Key employee Highest compensated Former  Reportable comp  \
# ...

# %% [markdown]
# Unsupervised learning - to identify clusters of similar NTEE descriptions, then based on these clusters, model to find salaries.
